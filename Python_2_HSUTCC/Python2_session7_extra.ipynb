# %% [markdown]
# # Python 2 HSUTCC: Session 7: Special Task

# %% [markdown]
# ## Special Task (Bonus 8% - Deadline Thursday 27 Nov 2025)

# %% [markdown]
# Symbolic differentiation allows to calculate a value of a derivative for an expression in a form of a sequence of symbols. Humans are likely to make mistakes during a long monotonous work and calculating of a direvative even not that hard but tidious process. Systems of symbolic calculations, like in this <a href='https://www.wolframalpha.com/input?i=derivate+x%5E3+++(1+-+x)+/+(1+-+x%5E2)'>example</a> are dedicated to save humanity from the need to spend their time for a potentially wrong calcuations.
#
# We will try to implement a simple system of symbolic differentiation on Python. The main type in our system will be a class `Expr` – an expression. All successor of the class should implement:
#
# - `__call__` method which calculates a value of an expression in a specified context: the context bounds names of variables in the expression with specific values.
# - `d` (Leibniz's notation of derivative) method which takes a name of a variable wrt (from “with respect to”) and returns an expression for a derivative with respect to this variable.

# %%
class Expr:
    def __call__(self, **context):
        raise NotImplementedError()
    
    def d(self, wrt):
        raise NotImplementedError()
    
    def __str__(self):
        raise NotImplementedError()
    
    def __repr__(self):
        return str(self)

# %% [markdown]
# **Important**: For each class, implement a `__str__` method which should return a corresponding formula in a form of S-expression.

# %% [markdown]
# 1. Implement class for two types of expressions: `Const` – a constant and `Var` – a variable. For convinience next we will use not a constructors of classes but their one-letter synonyms:

# %% [markdown]
# ```python
# V = Var
# C = Const
# ```

# %% [markdown]
# Example of class usage:

# %% [markdown]
# ---

# %% [markdown]
# ```python
# C(42)() # print(C(42)) -> 42
# ```

# %% [markdown]
# ```terminal
# 42
# ```

# %% [markdown]
# ---

# %% [markdown]
# ```python
# C(42).d(V("x"))() # print(C(42).d(V("x"))) -> 0
# ```

# %% [markdown]
# ```terminal
# 0
# ```

# %% [markdown]
# ---

# %% [markdown]
# ```python
# V("x")(x=42) # print(V("x")) -> x
# ```

# %% [markdown]
# ```terminal
# 42
# ```

# %% [markdown]
# ---

# %% [markdown]
# ```python
# V("x").d(V("x"))() # print(V("x").d(V("x"))) -> 1
# ```

# %% [markdown]
# ```terminal
# 1
# ```

# %% [markdown]
# ---

# %% [markdown]
# ```python
# V("x").d(V("y"))() # print(V("x").d(V("x"))) -> 0
# ```

# %% [markdown]
# ---

# %%
class Const(Expr):
    def __init__(self, value):
        self.value = value
    
    def __call__(self, **context):
        return self.value
    
    def d(self, wrt):
        # derivative of a constant = 0
        return Const(0)

    def __str__(self):
        return str(self.value)
    
class Var(Expr):
    def __init__(self, name):
        self.name = name
        
    def __call__(self, **context):
        return context[self.name]
    
    def d(self, wrt):
        # with respects to is an Expression, so extract its var name
        return Const(1) if self.name == wrt.name else Const(0)
    
    def __str__(self):
        return self.name

# %% [markdown]
# 2. Implement classes for binary operations: `Sum`, `Product`, and `Fraction`. Binary operations by definition work with exactly two operands that’s why a constructor for all binary classes will be the same. It’s convinient to take it out into a separate base class:

# %%
class BinOp(Expr):
    def __init__(self, expr1: Expr, expr2: Expr) -> None:
        self.expr1 = expr1
        self.expr2 = expr2

# %% [markdown]
# An example of using of some binary operations:

# %% [markdown]
# ---

# %% [markdown]
# ```python
# # x + x^2
# x = V("x")
# Sum(x, Product(x, x)).d(x)(x=42) # (+ 1 (+ (* 1 x) (* x 1)))
# ```

# %% [markdown]
# ```terminal
# 85
# ```

# %% [markdown]
# ---

# %% [markdown]
# ```python
# Product(x, Sum(x, C(2)))(x=42) # (* x (+ x 2))
# ```

# %% [markdown]
# ```terminal
# 1848
# ```

# %% [markdown]
# ---

# %% [markdown]
# ```python
# Fraction(Product(x, V("y")), Sum(C(42), x)).d(x)(x=42, y=24)
# ```

# %% [markdown]
# ```terminal
# 0.14285714285714285
# ```

# %% [markdown]
# ---

# %% [markdown]
# ```python
# Fraction(Product(x, V("y")), Sum(C(42), x)).d(V("y"))(x=42, y=24)
# ```

# %% [markdown]
# ```terminal
# 0.5
# ```

# %% [markdown]
# ---

# %%
class Sum(BinOp):
    def __call__(self, **context):
        return self.expr1(**context) + self.expr2(**context)
    
    def d(self, wrt):
        return Sum(self.expr1.d(wrt), self.expr2.d(wrt))
    
    def __str__(self):
        return f"(+ {self.expr1} {self.expr2})"

class Product(BinOp):
    def __call__(self, **context):
        return self.expr1(**context) * self.expr2(**context)
    
    def d(self, wrt):
        return Sum(
            Product(self.expr1.d(wrt), self.expr2),
            Product(self.expr1, self.expr2.d(wrt))
        )
    
    def __str__(self):
        return f"(* {self.expr1} {self.expr2})"

class Fraction(BinOp):
    def __call__(self, **context):
        return self.expr1(**context) / self.expr2(**context)
    
    def d(self, wrt):
        num = Sum(
            Product(self.expr1.d(wrt), self.expr2),
            Product(Const(-1), Product(self.expr1, self.expr2.d(wrt)))
        )
        den = Product(self.expr2, self.expr2)
        return Fraction(num, den)

    def __str__(self):
        return f"(/ {self.expr1} {self.expr2})"

# %% [markdown]
# 3. Implement a class `Power` for an operation of an exponentiation operation. For simplicity you can expect that a power – is an expression consisting only of constants.

# %% [markdown]
# ---

# %% [markdown]
# ```python
# Power(Fraction(V("x"), C(4)), C(2))(x=42) # (** (/ x 4) 2)
# ```

# %% [markdown]
# ```terminal
# 110.25
# ```

# %% [markdown]
# ---

# %% [markdown]
# ```python
# Power(Fraction(V("x"), C(4)), C(2)).d(V("x"))(x=42)
# ```

# %% [markdown]
# ```terminal
# 5.25
# ```

# %% [markdown]
# ---

# %%
class Power(BinOp):
    def __call__(self, **context):
        return self.expr1(**context) ** self.expr2(**context)
    
    def d(self, wrt):
        """exponent must be a const"""
        if not isinstance(self.expr2, Const):
            raise ValueError("Exponent must be a constant expression.")
        
        constant = self.expr2.value
        
        # derivative: constant * (expr1 ** (constant - 1)) * expr1 )
        return Product(
            Const(constant),
            Product(Power(self.expr1, Const(constant - 1)),
                    self.expr1.d(wrt))
        )
        
    def __str__(self):
        return f"(** {self.expr1} {self.expr2})"

# %% [markdown]
# 4. Implement an overloading of arithmetic operators for a base class Expr. Overall there are needed to be implement 7 operators: 2 unary and 5 binary:

# %% [markdown]
# ```terminal
# -e          e.__neg__()
# +e          e.__pos__()
# e1 + e2     e1.__add__(e2)
# e1 - e2     e1.__sub__(e2)
# e1 * e2     e1.__mul__(e2)
# e1 / e2     e1.__truediv__(e2)
# e1 ** e2    e1.__pow__(e2)
# ```

# %% [markdown]
# ---

# %% [markdown]
# ```python
# ((C(1) - V("x")) ** C(3) + V("x"))(x=12)
# ```

# %% [markdown]
# ```terminal
# -1319
# ```

# %% [markdown]
# ---

# %%
class Expr():
    def __call__(self, **context):
        raise NotImplementedError()

    def d(self, wrt):
        raise NotImplementedError()
    
    def __str__(self):
        raise NotImplementedError()
    
    def __repr__(self):
        raise NotImplementedError()

    # Overloading of arithmetic operators
    def __neg__(self):
        # -e = (* -1 e)
        return Product(Const(-1), self)
    
    def __pos__(self):
        # +e just returns the same expression
        return self
    
    # Binary operators
    def __add__(self, other):
        return Sum(self, other)
    
    def __sub__(self, other):
        return Sum(self, -other) # e1 - e2 = e1 + (-e2)
    
    def __mul__(self, other):
        return Product(self, other)
    
    def __truediv__(self, other):
        return Fraction(self, other)
    
    def __pow__(self, other):
        return Power(self, other)

# %%
# To test your implementation, put all other classes here
# Restart the kernel, run the above and current cell, then do some testing

class Expr:
    def __call__(self, **context):
        """ evaluate the expression numerically (Every subclass will implement this.)"""
        raise NotImplementedError()
    
    def d(self, wrt):
        """ Return the symbolic derivative of this expression with respect to the variable wrt"""
        raise NotImplementedError()
    
    def __str__(self):
        """ Return a string representation in S-expression style
            e.g. (+ x 1), (* x X)"""
        raise NotImplementedError()

    def __repr__(self):
        """ Just calls str() for nicer debugging."""
        return str(self)

    def __neg__(self):
        """Implement unary minus: -e
           Mathematically this is just (-1) * e,
           so we construct Product(Const(-1)., self) """
        return Product(Const(-1), self)
    
    def __pos__(self):
        """implements +e and just returns the same expression"""
        return self

    def __add__(self, other):
        """Implement e1 + e2 -> Sum(e1, e2)"""
        return Sum(self, other)
    
    def __sub__(self, other):
        """ e1 - e2  =  e1 + (-e2)
            we reuse __neg__ and Sum instead of creating new subclass"""
        return Sum(self, -other)
    
    def __mul__(self, other):
        """Implement e1 * e2 -> Product(e1, e2)"""
        return Product(self, other)
    
    def __truediv__(self, other):
        """Implement e1 / e2 -> Fraction(e1, e2)"""
        return Fraction(self, other)
    
    def __pow__(self, other):
        """Implement e1 ** e2 -> Power(e1, e2)"""
        return Power(self, other)

# variable expressions (X, Y)
class Const(Expr): 
    def __init__(self, value):
        """Store the constant numeric value"""
        self.value = value
    
    def __call__(self, **context):
        """A constant ignores context and always returns its value"""
        return self.value
    
    def d(self, wrt):
        """Derivative of a constant with respect to anything is 0"""
        return Const(0)

    def __str__(self):
        """Just show the raw value, e.g. 3 or 4.5"""
        return str(self.value)


class Var(Expr):
    
    def __init__(self, name):
        self.name = name
        
    def __call__(self, **context):
        """Look up the value of this variable in the context."""
        return context[self.name]
    
    def d(self, wrt):
        """Derivative of x wrt to x is 1.
           Derivative of x with respect to y is 0.
           wrt is a var instance, so we compare their names."""
        return Const(1) if self.name == wrt.name else Const(0)
    
    def __str__(self):
        """Just variable name e.g X"""
        return self.name 
    
    def __repr__(self):
        """Same as __str__ for nicer printing"""
        return str(self)

# Base class for binary operations
class BinOp(Expr): 
    """Store the left and right operands"""
    def __init__(self, expr1: Expr, expr2: Expr) -> None:
        self.expr1 = expr1
        self.expr2 = expr2

# Sum: expr1 + expr2
class Sum(BinOp): 
    def __call__(self, **context):
        # Evaluate both operands and add them
        return self.expr1(**context) + self.expr2(**context)
    
    def d(self, wrt):
        # (f + g) = f + g
        return Sum(self.expr1.d(wrt), self.expr2.d(wrt))
    
    def __str__(self):
        # S-expression: (+ expr1 expr2)
        return f"(+ {self.expr1} {self.expr2})"


class Product(BinOp):
    def __call__(self, **context):
        # Evaluate both operands and multiply them
        return self.expr1(**context) * self.expr2(**context)
    
    def d(self, wrt):
        # Product rule: (f * g) = f * g + f * g
        return Sum(
            Product(self.expr1.d(wrt), self.expr2),
            Product(self.expr1, self.expr2.d(wrt))
        )
    
    def __str__(self):
        # S-expression: (* expr1 expr2)
        return f"(* {self.expr1} {self.expr2})"


class Fraction(BinOp):
    def __call__(self, **context):
        # Evaluate numerator and denominator and divide
        return self.expr1(**context) / self.expr2(**context)
    
    def d(self, wrt):
        """Quotient rule: (f / g)' = (f' g - f g') / g^2
        We implement it as:
            num = f' g + (-1) * (f g')
            den = g * g
            result = num / den"""
        num = Sum(
            Product(self.expr1.d(wrt), self.expr2),
            Product(Const(-1), Product(self.expr1, self.expr2.d(wrt)))
        )
        den = Product(self.expr2, self.expr2)
        return Fraction(num, den)

    def __str__(self):
        # S - expression: (/ expr1 expr2)
        return f"(/ {self.expr1} {self.expr2})"

# Power: expr1 ** expr2 (exponent assumed to be a Const)
class Power(BinOp):
    def __call__(self, **context):
        # Evaluate base and exponent and raise to the power
        return self.expr1(**context) ** self.expr2(**context)
    
    def d(self, wrt):
        """Exponent must be a Const."""
        if not isinstance(self.expr2, Const):
            raise ValueError("Exponent must be a constant expression.")
        
        c = self.expr2.value
        
        # derivative: c * (expr1 ** (c - 1)) * expr1'
        return Product(
            Const(c),
            Product(
                Power(self.expr1, Const(c - 1)),
                self.expr1.d(wrt)
            )
        )
        
    def __str__(self):
        return f"(** {self.expr1} {self.expr2})"
C = Const
V = Var

# Testing the class

# Define variable x
x = V("x")

# Build expression: x^2 + 3x + 1
f = x**C(2) + C(3)*x + C(1)

print("f(x) as S-expression:", f)
print("f(2) =", f(x=2))  # evaluate at x = 2

# Derivative: f'(x)
df = f.d(V("x"))
print("f'(x) as S-expression:", df)
print("f'(2) =", df(x=2))  # evaluate derivative at x = 2

# Test 2 given expression g(x) = (1 - x)*** + x
x = V("x")

g = (C(1) - x) ** C(3) + x

print("g(x) as S-expression:", g)
print("g(12) =", g(x=12))

dg = g.d(V("x"))
print("g'(x) as S-expression:", dg)
print("g'(12) =", dg(x=12))
# Out:
# f(x) as S-expression: (+ (+ (** x 2) (* 3 x)) 1)
# f(2) = 11
# f'(x) as S-expression: (+ (+ (* 2 (* (** x 1) 1)) (+ (* 0 x) (* 3 1))) 0)
# f'(2) = 7
# g(x) as S-expression: (+ (** (+ 1 (* -1 x)) 3) x)
# g(12) = -1319
# g'(x) as S-expression: (+ (* 3 (* (** (+ 1 (* -1 x)) 2) (+ 0 (+ (* 0 x) (* -1 1))))) 1)
# g'(12) = -362
